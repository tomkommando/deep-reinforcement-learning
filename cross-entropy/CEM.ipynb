# %% [markdown]
# # Cross-Entropy Method
#
# ---
#
# In this notebook, we will train the Cross-Entropy Method with OpenAI Gym's MountainCarContinuous environment.

# %% [markdown]
# ### 1. Import the Necessary Packages

# %%
import gym
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import torch
import torch.nn as nn
#import torch.nn.tanh as tanh

from torch.autograd import Variable

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env = gym.make('MountainCarContinuous-v0')
env.seed(101)
np.random.seed(101)

print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('  - low:', env.action_space.low)
print('  - high:', env.action_space.high)

class Agent(nn.Module):
    def __init__(self, env, h_size=16):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)
        
    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))
    
    def get_weights_dim(self):
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        return x.cpu().data
        
    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            action = self.forward(state)
            state, reward, done, _ = self.env.step(action)
            episode_return += reward * math.pow(gamma, t)
            if done:
                break
        return episode_return
    
agent = Agent(env).to(device)
# Out:
# observation space: Box(2,)
# action space: Box(1,)
#   - low: [-1.]
#   - high: [1.]

# %% [markdown]
# ### 3. Train the Agent with the Cross-Entropy Method
#
# Run the code cell below to train the agent from scratch.  Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def cem(n_iterations=5000, max_t=1000, gamma=0.999, print_every=10, pop_size=50, elite_frac=0.2, sigma=0.5):
    """PyTorch implementation of the cross-entropy method.
        
    Params
    ======
        n_iterations (int): maximum number of training iterations
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        pop_size (int): size of population at each iteration
        elite_frac (float): percentage of top performers to use in update
        sigma (float): standard deviation of additive noise
    """
    n_elite=int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())

    for i_iteration in range(1, n_iterations+1):
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])

        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        best_weight = np.array(elite_weights).mean(axis=0)

        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        
        torch.save(agent.state_dict(), 'checkpoint.pth')
        
        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

#         if np.mean(scores_deque)>=200.0:
#             print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))
#             break
    return scores

# %%
print(f"start_time: {time.ctime()}\n")
scores = cem()
print(f"\nend time_time: {time.ctime()}")
# Out:
# start_time: Fri Aug 28 07:27:18 2020
#
# Episode 10	Average Score: -1.44
# Episode 20	Average Score: -2.68
# Episode 30	Average Score: -2.61
# Episode 40	Average Score: 7.93
# Episode 50	Average Score: 22.08
# Episode 60	Average Score: 33.99
# Episode 70	Average Score: 42.60
# Episode 80	Average Score: 48.98
# Episode 90	Average Score: 53.99
# Episode 100	Average Score: 57.95
# Episode 110	Average Score: 67.45
# Episode 120	Average Score: 77.21
# Episode 130	Average Score: 86.82
# Episode 140	Average Score: 92.17
# Episode 150	Average Score: 93.76
# Episode 160	Average Score: 93.70
# Episode 170	Average Score: 93.61
# Episode 180	Average Score: 93.57
# Episode 190	Average Score: 93.57
# Episode 200	Average Score: 93.57
# Episode 210	Average Score: 93.51
# Episode 220	Average Score: 93.48
# Episode 230	Average Score: 93.51
# Episode 240	Average Score: 93.59
# Episode 250	Average Score: 93.53
# Episode 260	Average Score: 93.63
# Episode 270	Average Score: 93.68
# Episode 280	Average Score: 93.69
# Episode 290	Average Score: 93.59
# Episode 300	Average Score: 93.59
# Episode 310	Average Score: 93.65
# Episode 320	Average Score: 93.69
# Episode 330	Average Score: 93.67
# Episode 340	Average Score: 93.65
# Episode 350	Average Score: 93.64
# Episode 360	Average Score: 93.59
# Episode 370	Average Score: 93.59
# Episode 380	Average Score: 93.47
# Episode 390	Average Score: 93.55
# Episode 400	Average Score: 93.57
# Episode 410	Average Score: 93.59
# Episode 420	Average Score: 93.59
# Episode 430	Average Score: 93.59
# Episode 440	Average Score: 93.59
# Episode 450	Average Score: 93.58
# Episode 460	Average Score: 93.47
# Episode 470	Average Score: 93.46
# Episode 480	Average Score: 93.56
# Episode 490	Average Score: 93.46
# Episode 500	Average Score: 93.45
# Episode 510	Average Score: 93.43
# Episode 520	Average Score: 93.43
# Episode 530	Average Score: 93.41
# Episode 540	Average Score: 93.41
# Episode 550	Average Score: 93.39
# Episode 560	Average Score: 93.43
# Episode 570	Average Score: 93.43
# Episode 580	Average Score: 93.47
# Episode 590	Average Score: 93.56
# Episode 600	Average Score: 93.55
# Episode 610	Average Score: 93.55
# Episode 620	Average Score: 93.55
# Episode 630	Average Score: 93.56
# Episode 640	Average Score: 93.53
# Episode 650	Average Score: 93.54
# Episode 660	Average Score: 93.63
# Episode 670	Average Score: 93.62
# Episode 680	Average Score: 93.61
# Episode 690	Average Score: 93.61
# Episode 700	Average Score: 93.60
# Episode 710	Average Score: 93.60
# Episode 720	Average Score: 93.60
# Episode 730	Average Score: 93.47
# Episode 740	Average Score: 93.48
# Episode 750	Average Score: 93.46
# Episode 760	Average Score: 93.45
# Episode 770	Average Score: 93.36
# Episode 780	Average Score: 93.37
# Episode 790	Average Score: 93.36
# Episode 800	Average Score: 93.35
# Episode 810	Average Score: 93.35
# Episode 820	Average Score: 93.35
# Episode 830	Average Score: 93.48
# Episode 840	Average Score: 93.48
# Episode 850	Average Score: 93.49
# Episode 860	Average Score: 93.42
# Episode 870	Average Score: 93.51
# Episode 880	Average Score: 93.50
# Episode 890	Average Score: 93.52
# Episode 900	Average Score: 93.52
# Episode 910	Average Score: 93.52
# Episode 920	Average Score: 93.52
# Episode 930	Average Score: 93.51
# Episode 940	Average Score: 93.46
# Episode 950	Average Score: 93.46
# Episode 960	Average Score: 93.54
# Episode 970	Average Score: 93.53
# Episode 980	Average Score: 93.54
# Episode 990	Average Score: 93.54
# Episode 1000	Average Score: 93.54
# Episode 1010	Average Score: 93.54
# Episode 1020	Average Score: 93.53
# Episode 1030	Average Score: 93.53
# Episode 1040	Average Score: 93.59
# Episode 1050	Average Score: 93.59
# Episode 1060	Average Score: 93.57
# Episode 1070	Average Score: 93.48
# Episode 1080	Average Score: 93.47
# Episode 1090	Average Score: 93.47
# Episode 1100	Average Score: 93.47
# Episode 1110	Average Score: 93.47
# Episode 1120	Average Score: 93.47
# Episode 1130	Average Score: 93.48
# Episode 1140	Average Score: 93.48
# Episode 1150	Average Score: 93.48
# Episode 1160	Average Score: 93.49
# Episode 1170	Average Score: 93.58
# Episode 1180	Average Score: 93.59
# Episode 1190	Average Score: 93.58
# Episode 1200	Average Score: 93.57
# Episode 1210	Average Score: 93.57
# Episode 1220	Average Score: 93.57
# Episode 1230	Average Score: 93.56
# Episode 1240	Average Score: 93.55
# Episode 1250	Average Score: 93.55
# Episode 1260	Average Score: 93.54
# Episode 1270	Average Score: 93.46
# Episode 1280	Average Score: 93.46
# Episode 1290	Average Score: 93.46
# Episode 1300	Average Score: 93.46
# Episode 1310	Average Score: 93.46
# Episode 1320	Average Score: 93.46
# Episode 1330	Average Score: 93.45
# Episode 1340	Average Score: 93.45
# Episode 1350	Average Score: 93.45
# Episode 1360	Average Score: 93.45
# Episode 1370	Average Score: 93.53
# Episode 1380	Average Score: 93.53
# Episode 1390	Average Score: 93.53
# Episode 1400	Average Score: 93.53
# Episode 1410	Average Score: 93.53
# Episode 1420	Average Score: 93.53
# Episode 1430	Average Score: 93.54
# Episode 1440	Average Score: 93.54
# Episode 1450	Average Score: 93.54
# Episode 1460	Average Score: 93.54
# Episode 1470	Average Score: 93.54
# Episode 1480	Average Score: 93.54
# Episode 1490	Average Score: 93.53
# Episode 1500	Average Score: 93.54
# Episode 1510	Average Score: 93.54
# Episode 1520	Average Score: 93.54
# Episode 1530	Average Score: 93.54
# Episode 1540	Average Score: 93.54
# Episode 1550	Average Score: 93.54
# Episode 1560	Average Score: 93.54
# Episode 1570	Average Score: 93.54
# Episode 1580	Average Score: 93.52
# Episode 1590	Average Score: 93.53
# Episode 1600	Average Score: 93.52
# Episode 1610	Average Score: 93.52
# Episode 1620	Average Score: 93.51
# Episode 1630	Average Score: 93.50
# Episode 1640	Average Score: 93.49
# Episode 1650	Average Score: 93.48
# Episode 1660	Average Score: 93.48
# Episode 1670	Average Score: 93.42
# Episode 1680	Average Score: 93.43
# Episode 1690	Average Score: 93.43
# Episode 1700	Average Score: 93.44
# Episode 1710	Average Score: 93.44
# Episode 1720	Average Score: 93.45
# Episode 1730	Average Score: 93.45
# Episode 1740	Average Score: 93.46
# Episode 1750	Average Score: 93.44
# Episode 1760	Average Score: 93.45
# Episode 1770	Average Score: 93.51
# Episode 1780	Average Score: 93.50
# Episode 1790	Average Score: 93.50
# Episode 1800	Average Score: 93.49
# Episode 1810	Average Score: 93.49
# Episode 1820	Average Score: 93.49
# Episode 1830	Average Score: 93.50
# Episode 1840	Average Score: 93.49
# Episode 1850	Average Score: 93.52
# Episode 1860	Average Score: 93.52
# Episode 1870	Average Score: 93.52
# Episode 1880	Average Score: 93.52
# Episode 1890	Average Score: 93.51
# Episode 1900	Average Score: 93.52
# Episode 1910	Average Score: 93.52
# Episode 1920	Average Score: 93.52
# Episode 1930	Average Score: 93.52
# Episode 1940	Average Score: 93.45
# Episode 1950	Average Score: 93.45
# Episode 1960	Average Score: 93.45
# Episode 1970	Average Score: 93.45
# Episode 1980	Average Score: 93.45
# Episode 1990	Average Score: 93.45
# Episode 2000	Average Score: 93.45
# Episode 2010	Average Score: 93.45
# Episode 2020	Average Score: 93.45
# Episode 2030	Average Score: 93.44
# Episode 2040	Average Score: 93.52
# Episode 2050	Average Score: 93.51
# Episode 2060	Average Score: 93.50
# Episode 2070	Average Score: 93.50
# Episode 2080	Average Score: 93.50
# Episode 2090	Average Score: 93.50
# Episode 2100	Average Score: 93.49
# Episode 2110	Average Score: 93.49
# Episode 2120	Average Score: 93.49
# Episode 2130	Average Score: 93.49
# Episode 2140	Average Score: 93.48
# Episode 2150	Average Score: 93.49
# Episode 2160	Average Score: 93.49
# Episode 2170	Average Score: 93.49
# Episode 2180	Average Score: 93.49
# Episode 2190	Average Score: 93.49
# Episode 2200	Average Score: 93.49
# Episode 2210	Average Score: 93.50
# Episode 2220	Average Score: 93.50
# Episode 2230	Average Score: 93.51
# Episode 2240	Average Score: 93.52
# Episode 2250	Average Score: 93.52
# Episode 2260	Average Score: 93.52
# Episode 2270	Average Score: 93.53
# Episode 2280	Average Score: 93.52
# Episode 2290	Average Score: 93.52
# Episode 2300	Average Score: 93.52
# Episode 2310	Average Score: 93.52
# Episode 2320	Average Score: 93.52
# Episode 2330	Average Score: 93.52
# Episode 2340	Average Score: 93.52
# Episode 2350	Average Score: 93.52
# Episode 2360	Average Score: 93.52
# Episode 2370	Average Score: 93.52
# Episode 2380	Average Score: 93.53
# Episode 2390	Average Score: 93.53
# Episode 2400	Average Score: 93.53
# Episode 2410	Average Score: 93.53
# Episode 2420	Average Score: 93.54
# Episode 2430	Average Score: 93.54
# Episode 2440	Average Score: 93.54
# Episode 2450	Average Score: 93.53
# Episode 2460	Average Score: 93.53
# Episode 2470	Average Score: 93.54
# Episode 2480	Average Score: 93.54
# Episode 2490	Average Score: 93.54
# Episode 2500	Average Score: 93.54
# Episode 2510	Average Score: 93.54
# Episode 2520	Average Score: 93.54
# Episode 2530	Average Score: 93.53
# Episode 2540	Average Score: 93.52
# Episode 2550	Average Score: 93.51
# Episode 2560	Average Score: 93.51
# Episode 2570	Average Score: 93.51
# Episode 2580	Average Score: 93.51
# Episode 2590	Average Score: 93.51
# Episode 2600	Average Score: 93.51
# Episode 2610	Average Score: 93.51
# Episode 2620	Average Score: 93.51
# Episode 2630	Average Score: 93.51
# Episode 2640	Average Score: 93.52
# Episode 2650	Average Score: 93.53
# Episode 2660	Average Score: 93.52
# Episode 2670	Average Score: 93.51
# Episode 2680	Average Score: 93.51
# Episode 2690	Average Score: 93.51
# Episode 2700	Average Score: 93.51
# Episode 2710	Average Score: 93.50
# Episode 2720	Average Score: 93.50
# Episode 2730	Average Score: 93.49
# Episode 2740	Average Score: 93.50
# Episode 2750	Average Score: 93.49
# Episode 2760	Average Score: 93.49
# Episode 2770	Average Score: 93.50
# Episode 2780	Average Score: 93.50
# Episode 2790	Average Score: 93.50
# Episode 2800	Average Score: 93.50
# Episode 2810	Average Score: 93.49
# Episode 2820	Average Score: 93.49
# Episode 2830	Average Score: 93.49
# Episode 2840	Average Score: 93.47
# Episode 2850	Average Score: 93.47
# Episode 2860	Average Score: 93.47
# Episode 2870	Average Score: 93.47
# Episode 2880	Average Score: 93.47
# Episode 2890	Average Score: 93.47
# Episode 2900	Average Score: 93.47
# Episode 2910	Average Score: 93.47
# Episode 2920	Average Score: 93.48
# Episode 2930	Average Score: 93.49
# Episode 2940	Average Score: 93.50
# Episode 2950	Average Score: 93.50
# Episode 2960	Average Score: 93.50
# Episode 2970	Average Score: 93.50
# Episode 2980	Average Score: 93.50
# Episode 2990	Average Score: 93.50
# Episode 3000	Average Score: 93.50
# Episode 3010	Average Score: 93.51
# Episode 3020	Average Score: 93.42
# Episode 3030	Average Score: 93.42
# Episode 3040	Average Score: 93.42
# Episode 3050	Average Score: 93.41
# Episode 3060	Average Score: 93.41
# Episode 3070	Average Score: 93.42
# Episode 3080	Average Score: 93.36
# Episode 3090	Average Score: 93.35
# Episode 3100	Average Score: 93.36
# Episode 3110	Average Score: 93.36
# Episode 3120	Average Score: 93.45
# Episode 3130	Average Score: 93.45
# Episode 3140	Average Score: 93.45
# Episode 3150	Average Score: 93.46
# Episode 3160	Average Score: 93.46
# Episode 3170	Average Score: 93.46
# Episode 3180	Average Score: 93.52
# Episode 3190	Average Score: 93.53
# Episode 3200	Average Score: 93.53
# Episode 3210	Average Score: 93.52
# Episode 3220	Average Score: 93.52
# Episode 3230	Average Score: 93.52
# Episode 3240	Average Score: 93.52
# Episode 3250	Average Score: 93.52
# Episode 3260	Average Score: 93.52
# Episode 3270	Average Score: 93.52
# Episode 3280	Average Score: 93.52
# Episode 3290	Average Score: 93.52
# Episode 3300	Average Score: 93.52
# Episode 3310	Average Score: 93.52
# Episode 3320	Average Score: 93.52
# Episode 3330	Average Score: 93.52
# Episode 3340	Average Score: 93.52
# Episode 3350	Average Score: 93.52
# Episode 3360	Average Score: 93.52
# Episode 3370	Average Score: 93.51
# Episode 3380	Average Score: 93.51
# Episode 3390	Average Score: 93.51
# Episode 3400	Average Score: 93.51
# Episode 3410	Average Score: 93.51
# Episode 3420	Average Score: 93.51
# Episode 3430	Average Score: 93.51
# Episode 3440	Average Score: 93.51
# Episode 3450	Average Score: 93.50
# Episode 3460	Average Score: 93.50
# Episode 3470	Average Score: 93.50
# Episode 3480	Average Score: 93.50
# Episode 3490	Average Score: 93.49
# Episode 3500	Average Score: 93.49
# Episode 3510	Average Score: 93.48
# Episode 3520	Average Score: 93.48
# Episode 3530	Average Score: 93.48
# Episode 3540	Average Score: 93.48
# Episode 3550	Average Score: 93.48
# Episode 3560	Average Score: 93.49
# Episode 3570	Average Score: 93.49
# Episode 3580	Average Score: 93.48
# Episode 3590	Average Score: 93.48
# Episode 3600	Average Score: 93.48
# Episode 3610	Average Score: 93.48
# Episode 3620	Average Score: 93.48
# Episode 3630	Average Score: 93.48
# Episode 3640	Average Score: 93.48
# Episode 3650	Average Score: 93.48
# Episode 3660	Average Score: 93.47
# Episode 3670	Average Score: 93.47
# Episode 3680	Average Score: 93.48
# Episode 3690	Average Score: 93.48
# Episode 3700	Average Score: 93.48
# Episode 3710	Average Score: 93.48
# Episode 3720	Average Score: 93.48
# Episode 3730	Average Score: 93.48
# Episode 3740	Average Score: 93.48
# Episode 3750	Average Score: 93.48
# Episode 3760	Average Score: 93.48
# Episode 3770	Average Score: 93.48
# Episode 3780	Average Score: 93.47
# Episode 3790	Average Score: 93.47
# Episode 3800	Average Score: 93.47
# Episode 3810	Average Score: 93.46
# Episode 3820	Average Score: 93.47
# Episode 3830	Average Score: 93.47
# Episode 3840	Average Score: 93.47
# Episode 3850	Average Score: 93.47
# Episode 3860	Average Score: 93.47
# Episode 3870	Average Score: 93.48
# Episode 3880	Average Score: 93.48
# Episode 3890	Average Score: 93.48
# Episode 3900	Average Score: 93.48
# Episode 3910	Average Score: 93.49
# Episode 3920	Average Score: 93.49
# Episode 3930	Average Score: 93.49
# Episode 3940	Average Score: 93.48
# Episode 3950	Average Score: 93.48
# Episode 3960	Average Score: 93.48
# Episode 3970	Average Score: 93.48
# Episode 3980	Average Score: 93.48
# Episode 3990	Average Score: 93.48
# Episode 4000	Average Score: 93.47
# Episode 4010	Average Score: 93.48
# Episode 4020	Average Score: 93.47
# Episode 4030	Average Score: 93.47
# Episode 4040	Average Score: 93.47
# Episode 4050	Average Score: 93.47
# Episode 4060	Average Score: 93.47
# Episode 4070	Average Score: 93.47
# Episode 4080	Average Score: 93.47
# Episode 4090	Average Score: 93.47
# Episode 4100	Average Score: 93.47
# Episode 4110	Average Score: 93.47
# Episode 4120	Average Score: 93.47
# Episode 4130	Average Score: 93.47
# Episode 4140	Average Score: 93.47
# Episode 4150	Average Score: 93.47
# Episode 4160	Average Score: 93.47
# Episode 4170	Average Score: 93.47
# Episode 4180	Average Score: 93.39
# Episode 4190	Average Score: 93.39
# Episode 4200	Average Score: 93.39
# Episode 4210	Average Score: 93.39
# Episode 4220	Average Score: 93.39
# Episode 4230	Average Score: 93.39
# Episode 4240	Average Score: 93.40
# Episode 4250	Average Score: 93.40
# Episode 4260	Average Score: 93.40
# Episode 4270	Average Score: 93.40
# Episode 4280	Average Score: 93.47
# Episode 4290	Average Score: 93.47
# Episode 4300	Average Score: 93.47
# Episode 4310	Average Score: 93.47
# Episode 4320	Average Score: 93.47
# Episode 4330	Average Score: 93.47
# Episode 4340	Average Score: 93.47
# Episode 4350	Average Score: 93.47
# Episode 4360	Average Score: 93.48
# Episode 4370	Average Score: 93.47
# Episode 4380	Average Score: 93.47
# Episode 4390	Average Score: 93.47
# Episode 4400	Average Score: 93.47
# Episode 4410	Average Score: 93.47
# Episode 4420	Average Score: 93.47
# Episode 4430	Average Score: 93.47
# Episode 4440	Average Score: 93.47
# Episode 4450	Average Score: 93.47
# Episode 4460	Average Score: 93.47
# Episode 4470	Average Score: 93.47
# Episode 4480	Average Score: 93.47
# Episode 4490	Average Score: 93.47
# Episode 4500	Average Score: 93.47
# Episode 4510	Average Score: 93.47
# Episode 4520	Average Score: 93.47
# Episode 4530	Average Score: 93.47
# Episode 4540	Average Score: 93.47
# Episode 4550	Average Score: 93.47
# Episode 4560	Average Score: 93.47
# Episode 4570	Average Score: 93.48
# Episode 4580	Average Score: 93.48
# Episode 4590	Average Score: 93.49
# Episode 4600	Average Score: 93.49
# Episode 4610	Average Score: 93.50
# Episode 4620	Average Score: 93.51
# Episode 4630	Average Score: 93.52
# Episode 4640	Average Score: 93.52
# Episode 4650	Average Score: 93.52
# Episode 4660	Average Score: 93.52
# Episode 4670	Average Score: 93.52
# Episode 4680	Average Score: 93.51
# Episode 4690	Average Score: 93.51
# Episode 4700	Average Score: 93.46
# Episode 4710	Average Score: 93.44
# Episode 4720	Average Score: 93.43
# Episode 4730	Average Score: 93.43
# Episode 4740	Average Score: 93.40
# Episode 4750	Average Score: 93.40
# Episode 4760	Average Score: 93.40
# Episode 4770	Average Score: 93.41
# Episode 4780	Average Score: 93.41
# Episode 4790	Average Score: 93.41
# Episode 4800	Average Score: 93.47
# Episode 4810	Average Score: 93.48
# Episode 4820	Average Score: 93.49
# Episode 4830	Average Score: 93.50
# Episode 4840	Average Score: 93.52
# Episode 4850	Average Score: 93.52
# Episode 4860	Average Score: 93.52
# Episode 4870	Average Score: 93.51
# Episode 4880	Average Score: 93.52
# Episode 4890	Average Score: 93.51
# Episode 4900	Average Score: 93.52
# Episode 4910	Average Score: 93.52
# Episode 4920	Average Score: 93.52
# Episode 4930	Average Score: 93.51
# Episode 4940	Average Score: 93.51
# Episode 4950	Average Score: 93.51
# Episode 4960	Average Score: 93.51
# Episode 4970	Average Score: 93.52
# Episode 4980	Average Score: 93.52
# Episode 4990	Average Score: 93.52
# Episode 5000	Average Score: 93.51
#
# end time_time: Fri Aug 28 13:40:10 2020

# %%
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
# load the weights from file
agent.load_state_dict(torch.load('checkpoint.pth'))

state = env.reset()
env.render()
time.sleep(5)
while True:
    state = torch.from_numpy(state).float().to(device)
    with torch.no_grad():
        action = agent(state)
        action = env.action_space.sample()
    env.render()
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()
